# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv("../Datasets/surviving-mars-maps/MapData-Evans-GP.csv")
df.dropna
# Out:
# <bound method DataFrame.dropna of        Latitude ° Latitude  Longitude ° Longitude       Topography  \
# 0               0        S            0         E  Relatively Flat
# 1               0        S            1         E  Relatively Flat
# 2               0        S            1         W  Relatively Flat
# 3               0        S            2         E  Relatively Flat
# 4               0        S            2         W  Relatively Flat
# ...           ...      ...          ...       ...              ...
# 50896          70        N          179         W  Relatively Flat
# 50897          70        S          180         E            Steep
# 50898          70        S          180         W  Relatively Flat
# 50899          70        N          180         E  Relatively Flat
# 50900          70        N          180         W  Relatively Flat
#
#        Difficulty Challenge  Altitude  Temperature  Metals  Rare Metals  ...  \
# ...

# %%
df.head()
# Out:
#    Latitude ° Latitude  Longitude ° Longitude       Topography  \
# 0           0        S            0         E  Relatively Flat
# 1           0        S            1         E  Relatively Flat
# 2           0        S            1         W  Relatively Flat
# 3           0        S            2         E  Relatively Flat
# 4           0        S            2         W  Relatively Flat
#
#    Difficulty Challenge  Altitude  Temperature  Metals  Rare Metals  ...  \
# 0                   140      -929           -1       2            2  ...
# 1                   100     -1160           -1       2            2  ...
# 2                   100     -1160           -3       2            2  ...
# 3                   140     -1160           -1       2            2  ...
# 4                   100      -929           -3       2            2  ...
#
#               Breakthrough 8             Breakthrough 9  \
# 0  Superconducting Computing      Construction Nanites
# ...

# %%
df.dtypes
# Out:
# Latitude °               int64
# Latitude                object
# Longitude °              int64
# Longitude               object
# Topography              object
# Difficulty Challenge     int64
# Altitude                 int64
# Temperature              int64
# Metals                   int64
# Rare Metals              int64
# Concrete                 int64
# Water                    int64
# Dust Devils              int64
# Dust Storms              int64
# Meteors                  int64
# Cold Waves               int64
# Map Name                object
# Named Location          object
# Breakthrough 1          object
# Breakthrough 2          object
# Breakthrough 3          object
# Breakthrough 4          object
# Breakthrough 5          object
# Breakthrough 6          object
# Breakthrough 7          object
# Breakthrough 8          object
# Breakthrough 9          object
# Breakthrough 10         object
# Breakthrough 11         object
# Breakthrough 12         object
# ...

# %%
df.describe()
# Out:
#          Latitude °   Longitude °  Difficulty Challenge      Altitude  \
# count  50901.000000  50901.000000          50901.000000  50901.000000
# mean      35.248227     90.249307            133.196204   -425.882576
# std       20.352820     52.106773             34.572810   2927.879760
# min        0.000000      0.000000            100.000000  -8200.000000
# 25%       18.000000     45.000000            100.000000  -3353.000000
# 50%       35.000000     90.000000            140.000000   -121.000000
# 75%       53.000000    135.000000            140.000000   1840.000000
# max       70.000000    180.000000            240.000000  21229.000000
#
#        Temperature        Metals   Rare Metals      Concrete         Water  \
# count  50901.00000  50901.000000  50901.000000  50901.000000  50901.000000
# mean     -35.55828      2.434962      2.434962      2.207069      2.703287
# std       30.46709      0.784851      0.784851      1.141824      1.153535
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50901 entries, 0 to 50900
# Data columns (total 35 columns):
# Latitude °              50901 non-null int64
# Latitude                50901 non-null object
# Longitude °             50901 non-null int64
# Longitude               50901 non-null object
# Topography              50901 non-null object
# Difficulty Challenge    50901 non-null int64
# Altitude                50901 non-null int64
# Temperature             50901 non-null int64
# Metals                  50901 non-null int64
# Rare Metals             50901 non-null int64
# Concrete                50901 non-null int64
# Water                   50901 non-null int64
# Dust Devils             50901 non-null int64
# Dust Storms             50901 non-null int64
# Meteors                 50901 non-null int64
# Cold Waves              50901 non-null int64
# Map Name                50901 non-null object
# Named Location          11925 non-null object
# ...

# %%
x = df['Temperature']
y = df['Altitude']

sns.set_style('whitegrid')
sns.distplot(x, hist = False)

# %%
sns.distplot(y, hist = False)

# %%
ax = sns.heatmap(df.corr())

# %%
df[df.dtypes[(df.dtypes=="float64")|(df.dtypes=="int64")].index.values].hist(figsize=[11,11])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000199B9283408>,
# ...
#       dtype=object)

# %%
min_max = MinMaxScaler()
X_MM=min_max.fit_transform(df[df.dtypes[(df.dtypes=="float64")|(df.dtypes=="int64")].index.values])
print(X_MM)
# Out:
# [[0.         0.         0.28571429 ... 0.         1.         0.        ]
#  [0.         0.00555556 0.         ... 0.         1.         0.        ]
#  [0.         0.00555556 0.         ... 0.33333333 1.         0.        ]
#  ...
#  [1.         1.         0.28571429 ... 0.         0.         1.        ]
#  [1.         1.         0.28571429 ... 0.33333333 0.         1.        ]
#  [1.         1.         0.28571429 ... 0.         0.         1.        ]]

# %%
sns.boxplot(x = df["Temperature"])

# %%
sns.boxplot(x = df["Altitude"])

# %%
sns.scatterplot(x, y, size_norm = 3)
